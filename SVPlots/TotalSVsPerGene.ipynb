# %%
# %matplotlib inline

import json
import urllib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.patches import Polygon
from scipy import stats

import dataParser as parser
import helperFiles.buildPlot as plotBuilder
# import mpld3
# mpld3.enable_notebook()

# %%
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# %%
samples = parser.samples

labels = []
forplot = []
counter = 0
for i in samples:
    for gene in samples[i]:
        print(gene)
        toAdd = parser.getNumOfSVs(gene)
        if(toAdd == None):
            continue
        else:
            labels.append(gene)
            forplot.append(toAdd)
# Out:
# XRCC6
# XRCC5
# PRKDC
# LIG4
# XRCC4
# DCLRE1C
# NHEJ1
# MRE11
# RAD50
# NBN
# RBBP8
# ERCC4
# ERCC1
# LIG1
# POLL
# POLB
# PARP1
# LIG3
# XRCC1
# RAD51
# RAD51B
# RAD51D
# DMC1
# XRCC2
# XRCC3
# RAD52
# RAD54L
# RAD54B
# BRCA1
# SHFM1
# HTTP Error 400: Bad Request
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/SHFM1?content-type=application/json;expand=1
# symb got fricked
# RAD50
# MRE11
# NBN
# RBBP8
# MUS81
# EME1
# EME2
# GIYD1
# HTTP Error 400: Bad Request
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/GIYD1?content-type=application/json;expand=1
# symb got fricked
# GIYD2
# HTTP Error 400: Bad Request
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/GIYD2?content-type=application/json;expand=1
# symb got fricked
# GEN1
# UNG
# SMUG1
# MBD4
# TDG
# OGG1
# MUTYH
# NTHL1
# MPG
# NEIL1
# NEIL2
# NEIL3
# APEX1
# APEX2
# invalid literal for int() with base 10: 'X'
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/APEX2?content-type=application/json;expand=1
# symb got fricked
# LIG3
# XRCC1
# PNKP
# APLF
# PARP1
# PARP2
# PARP3
# MGMT
# ALKBH2
# ALKBH3
# TDP1
# TDP2
# MSH2
# MSH3
# MSH6
# MLH1
# PMS2
# MSH4
# MSH5
# MLH3
# PMS1
# PMS2L3
# HTTP Error 400: Bad Request
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/PMS2L3?content-type=application/json;expand=1
# symb got fricked
# RAD23B
# CETN2
# invalid literal for int() with base 10: 'X'
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/CETN2?content-type=application/json;expand=1
# symb got fricked
# RAD23A
# XPA
# DDB1
# DDB2
# RPA1
# RPA2
# RPA3
# TFIIH
# HTTP Error 400: Bad Request
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/TFIIH?content-type=application/json;expand=1
# symb got fricked
# ERCC3
# ERCC2
# GTF2H1
# GTF2H2
# GTF2H3
# GTF2H4
# GTF2H5
# CDK7
# CCNH
# MNAT1
# ERCC5
# ERCC1
# ERCC4
# LIG1
# ERCC8
# ERCC6
# UVSSA
# XAB2
# MMS19
# FANCA
# FANCB
# invalid literal for int() with base 10: 'X'
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/FANCB?content-type=application/json;expand=1
# symb got fricked
# FANCC
# BRCA2
# FANCD2
# FANCE
# FANCF
# FANCG
# FANCI
# BRIP1
# FANCL
# FANCM
# PALB2
# RAD51C
# BTBD12
# HTTP Error 400: Bad Request
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/BTBD12?content-type=application/json;expand=1
# symb got fricked
# FAAP20
# FAAP24
# NUDT1
# DUT
# RRM2B
# POLB
# POLG
# POLD1
# POLE
# PCNA
# REV3L
# MAD2L2
# REV1L
# HTTP Error 400: Bad Request
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/REV1L?content-type=application/json;expand=1
# symb got fricked
# POLH
# POLI
# POLQ
# POLK
# POLL
# POLM
# POLN
# FEN1
# FAN1
# TREX1
# TREX2
# invalid literal for int() with base 10: 'X'
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/TREX2?content-type=application/json;expand=1
# symb got fricked
# EXO1
# APTX
# SPO11
# ENDOV
# UBE2A
# invalid literal for int() with base 10: 'X'
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/UBE2A?content-type=application/json;expand=1
# symb got fricked
# UBE2B
# RAD18
# SHPRH
# HLTF
# RNF168
# SPRTN
# RNF8
# RNF4
# UBE2V2
# UBE2N
# H2AFX
# HTTP Error 400: Bad Request
# https://rest.ensembl.org/lookup/symbol/homo_sapiens/H2AFX?content-type=application/json;expand=1
# symb got fricked
# CHAF1A
# SETMAR
# ATR
# ATRIP
# MDC1
# RAD1
# RAD9A
# HUS1
# RAD17
# CHEK1
# CHEK2
# TP53
# TP53BP1
# RIF1
# TOPBP1
# CLK2
# PER1

# %%
fig, ax = plt.subplots(figsize=(10, 10))
print(forplot)
x = np.arange(len(labels))
rects = ax.bar(x, forplot)
ax.set_ylabel('Number of Total SVs')
ax.set_title('Number of SV in Genes')
ax.set_xticks(x)
plt.xticks(rotation=90)
ax.set_xticklabels(labels)
autolabel(rects)
mpld3.show()
# Out:
# [17, 10, 32, 1, 34, 13, 22, 8, 8, 17, 79, 1, 25, 8, 3, 24, 19, 7, 11, 2, 174, 5, 20, 3, 3, 20, 3, 19, 33, 8, 8, 17, 79, 5, 1, 4, 9, 2, 19, 0, 4, 8, 1, 4, 1, 1, 3, 6, 0, 7, 11, 2, 41, 19, 0, 0, 29, 1, 4, 10, 1, 42, 20, 22, 9, 1, 12, 6, 2, 11, 9, 4, 5, 4, 4, 22, 13, 13, 1, 3, 7, 2, 9, 0, 1, 0, 15, 34, 6, 25, 1, 8, 14, 9, 5, 1, 6, 30, 35, 14, 19, 5, 0, 1, 7, 61, 17, 5, 13, 25, 12, 9, 1, 1, 5, 24, 7, 11, 30, 2, 35, 2, 24, 8, 13, 16, 3, 1, 23, 3, 0, 0, 15, 41, 4, 8, 2, 36, 13, 18, 4, 2, 5, 36, 5, 14, 6, 2, 19, 5, 3, 2, 43, 2, 0, 1, 6, 7, 13, 12, 16, 7, 3]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-273a839c03f2> in <module>
#       9 ax.set_xticklabels(labels)
#      10 autolabel(rects)
# ---> 11 mpld3.show()
#
# NameError: name 'mpld3' is not defined
